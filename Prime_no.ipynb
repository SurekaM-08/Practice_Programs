# %%
j=1
while j<100:
    c=0
    for i in range(1,j+1):
        if j%1==0:
            c=c+1
    if c==2:
        print(j,"Prime number")
    j+=1
# Out:
# 2 Prime number

# %%
a=int(input("Enter a number"))
c=0
for i in range(1,a+1):
    if a%i==0:
        print(i)
        c=c+1
print(c)
if c==2:
    print("prime no")
else:
    print("Not prime")
# Out:
# Enter a number 57
# 1
# 3
# 19
# 57
# 4
# Not prime
